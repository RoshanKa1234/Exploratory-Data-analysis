# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df.set_index('id', inplace = True)

# %%
df.tail()

# %%
artist = df[['artist_name', 'track_name', 'popularity']]
artist.value_counts()
popu = df[['danceability','artist_name']]

# %%
ties = df['track_name'] == 'Streets'
popu = df['instrumentalness'] <= 0.0382
popu2 = df['popularity'] == 87
df.loc[(popu & popu2 & ties)]

# %%
df.sort_index(ascending = False)

# %%
df.head()

# %%
con = (df['popularity'] > 90) & (df['danceability'] >= 0.7) & (df['loudness'] <= -5.0)
df.loc[con]

# %% [markdown]
# # Using Nagation symbol
# Which means completely opposite

# %%
con = (df['popularity'] > 90) & (df['danceability'] >= 0.7) & (df['loudness'] <= -5.0)
df.loc[~con]

# %%
arrt = ['Joel Corry', 'Ariana Grande']
ko = df['artist_name'].isin(arrt)
df.loc[ko]

# %%
hu = df['artist_name'].str.contains('Ariana Grande', na = False)
df.loc[hu]

# %% [markdown]
# # In this Method only one string can be passed to search

# %%
kalu = df['artist_name'].str.contains('Joel Corry', na = False)
df.loc[kalu]

# %%
noise = (df['loudness'] <= -4.258500) & (df['speechiness'] <=  0.094300) & (df['liveness'] <=  0.246500) & (df['instrumentalness'] <= 0.000024) & (df['energy'] <= 0.76475)
df.loc[noise]

# %%
sel = df['artist_name']
sel.value_counts()

# %%
music = (df['danceability'] >= 0.714500) & (df['popularity'] <=  88.000000) & (df['liveness'] >=  0.115000) & (df['energy'] <= 0.76475)
df.loc[music,'artist_name']

# %%
kall = df['liveness']
kall.describe()

# %%
oli = ['Masked Wolf']
oliv = df['artist_name'].isin(oli)
df.loc[oliv]

# %%
oliv.value_counts()

# %%
ari = ['Masked Wolf']
ana = df['artist_name'].str.contains('Doja Cat', na = False)
df.loc[ana]

# %%
df1 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df1.set_index('id', inplace = True)

df1.columns = ['artist boy', 'track_boy', 'track_id', 'popularity', 'danceability',
       'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
       'time_signature']
df1.columns

# %%
df2 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df2.set_index('id', inplace = True)
df3 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df3.set_index('id', inplace = True)

def head_update(head):
    return head.title()

df3['artist_name'] = df3['artist_name'].apply(head_update)
df3.head(4)
# Other way to do it 
df2['time_signaturecopy'] = df2['time_signature'].apply(lambda x: x*x) # lambda function is not only working in this notebook only
df2.head(4)

# %% [markdown]
# ddf4 = ['duration_ms','time_signature','key']
# df4 = ddf4.applymap(lambda x: x + x)
# df4

# %%
df4 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df4.set_index('id', inplace = True)

df4['artist_name'] = df4['artist_name'].replace({'Olivia Rodrigo':'RK', 'Lil Nas X':'Roshan Kachwal'})
df4.head(3)

# %%
# rename function not proper
df6 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df6.set_index('id', inplace = True)

df6.rename(columns = {"artist_name": 'artist boy'},inplace = True, errors="raise")
df6.head(2)

# %%
df5 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df5.set_index('id', inplace = True)

df5['artist_name'] = df5['artist_name'].map({'Olivia Rodrigo': 'RK', 'Lil Nas X': 'Roshan Kachwal'})
df5.head(4) # In map function it only change the value of selected once and rest are given NaN

# %% [markdown]
# # Selecting the rows and columns using conditions and then changing the value

# %%
df8 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df8.set_index('id', inplace = True)
rodri = df['artist_name'].str.contains('Olivia Rodrigo')
df8.loc[rodri] = 'Roshan'
df8.head(3)

# %% [markdown]
# # Apply function only takes lamda or def function it doesn't accept any list or value
# filk = (df['artist_name'] == 'Roshan')
# df['artist_name'].apply(filk)

# %%
df7 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df7.set_index('id', inplace = True)

filk = (df7['artist_name'].str.contains('Roshan')) 
df7.loc[filk] = 'Olivia Rodrigo'
df7.head(3)

# %%
df6 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df6.set_index('id', inplace = True)

lst = ['Olivia Rodrigo']
filker = (df6['artist_name'].isin(lst))
df6.loc[filker]

# %%
df7 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df7.set_index('id', inplace = True)
df7['artist_name'] = df7['artist_name'].str.replace('Lil','littleThing', regex=False)
df7.head() # df7['artist_name'] = if its not given no changes will show in o/p

# %%
df8 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df8.set_index('id', inplace = True)

df8.rename(columns = {'track_name':'location_track','popularity': 'EGO'}, inplace = True)
df8.head(4)

# %%
df9 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df9.set_index('id', inplace = True)
df9.loc[1:5, 'artist_name': 'danceability'] = 'blow bubble'
df9.head(7)

# %% [markdown]
# ****at function exactly same as loc

# %%
df10 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df10.set_index('id', inplace = True)
lst_row = [1,2,3]
lst_col = [0,1,2]
df10.iloc[lst_row, lst_col] = 'blow bubble'
df10.head(5)

# %% [markdown]
# # Passing Numpy functions in apply (Eg:- np.sqrt)
#
# Adding New column in table using apply function

# %% [markdown]
# # ******# Apply function apply to specific column or rows (using axis), but applymap is applicable to whole table(df.applymap)

# %%
df11 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df11.set_index('id', inplace = True)

df11['sqt_popz'] = df11['popularity'].apply(np.sqrt)

df11.head(3)

# %%
df12 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df12.set_index('id', inplace = True)

df12['artist_name'] = df12['artist_name'].replace({'Olivia Rodrigo':'Selenia Gomezee'})
df12.head(5)

# %% [markdown]
# # Concatination of Column and Rows
# 1. It is applicable for strings only

# %%
df13 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df13.set_index('id', inplace = True)

df13['Combine'] = df13['artist_name'] + ',  ' + df13['track_name'] # Column concatination
df13.head(5)

# %%
df13.drop(columns = 'track_id', inplace = True)
df13.head(5)

# %%
df14 = pd.read_csv('../input/spotify-top-50-songs-in-2021/spotify_top50_2021.csv')
df14.set_index('id', inplace = True)

# %%
lsst = ['track_id', 'key', 'loudness', 'mode', 'instrumentalness', 'tempo']
df14.drop(columns = lsst, inplace = True)
df14.head()

# %%
df14['Extra_Stuff'] = df14['artist_name'] + ', ' + df14['track_name']
lsst2 = ['artist_name', 'track_name']
df14.drop(columns = lsst2, inplace = True)
df14.head()

# %% [markdown]
# # **First split the values into 2 list without assigning any variable
# # Assign 2 list in seprate column using expand function
# # Assign 2 variable to each new column**

# %%
df14[['artist_name', 'track_name']] = df14['Extra_Stuff'].str.split(', ', expand = True)
item = ['Extra_Stuff']
df14.drop(columns = item, inplace = True)
df14['new_stuff'] = df14['artist_name'] + ', ' + df14['track_name']
df14.head()

# %%
df14['new_stuff'].str.split(',')

# %%
df14['new_stuff'].str.split(',', expand = True)

# %%
df14[['first', 'last']] = df14['new_stuff'].str.split(',', expand = True)
item = ['new_stuff']
df14.drop(columns = item, inplace = True)
df14.head()
