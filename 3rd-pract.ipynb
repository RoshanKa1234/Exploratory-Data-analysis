# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)
df.set_index('id', inplace = True)

lister = df[['Brand', 'Processor', 'Hard_Disk_Capacity', 'Price']]
lister.value_counts()

# %%
df1 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df1.set_index('Unnamed: 0', inplace = True)
df1.head()

# %%
df1.drop(index = [1,3], inplace = True)
df1.drop(index = [4,5,6], inplace = True)
df1.head()

# %%
df3 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df3.set_index('Unnamed: 0', inplace = True)

# %%
brand_cond = (df3['Brand'] == 'ASUS') | (df3['Brand'] == 'Lenovo')
df3.drop(index = df3[brand_cond].index, inplace = True) #pass value in dataframe format and add index
df3.head(3)

# %%
df4 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df4.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)
df4.set_index('id', inplace = True)

brand_cond = df4['Brand'].str.contains('DELL')
df4.drop(index = df4[brand_cond].index, inplace = True)
df4.head()

# %%
df4.rename(index = {'Unnamed' : 'Company'}, inplace = True)
df4

# %%
df5 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df5.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)
df5.set_index('id', inplace = True)

# %% [markdown]
# # In rename function value has to be pass as a dictionary format
# E.g - {'RAM' : 'Random_Access_Memory'}

# %%
cols = {'RAM' : 'Random_Access_Memory'}
df5.rename(columns = cols, inplace = True) # cols passed i n dict format
df5.head()

# %%
dicto = {'Brand':'Roshan', 'Model':'Skilled','Series': 'i100'}
df5.append(dicto, ignore_index=True)

# %%
for i in range(131):
    dicton = {'Brand': i}
df5.append(dicton, ignore_index=True)

# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoelemail.com', 'JohnDoetemail.com']
}
data = pd.DataFrame(people)
data

# %%
for i in range(3):
    col_lst = {i:'Name'}
    data.rename(index = col_lst, inplace = True)
data.head()

# %% [markdown]
# ****In append function if the passed column does not exist it will create a new one and add the value in it

# %%
dicta = {'New_column':'Name'}
data.append(dicta, ignore_index=True)

# %%
df5.drop(index = 129) #here counting starts from 0 to 129

# %%
bran_dop = ['ASUS']
df5.drop(index = 2, inplace = True)
df5.head()

# %%
df5.drop('Series', axis = 1, inplace = True)
df5.head()

# %%
dictatat = {'Model': 'RK'}
df5.append(dictatat, ignore_index=True)

# %%
df5.append(data, ignore_index=True)
df5

# %%
df6 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df6.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)
df6.set_index('id', inplace = True)
 
df6.sort_values(by = 'Brand', ascending = False, inplace = True)
df6.head(15)

# %% [markdown]
# sort_values function is to sort columns and sort_index function is to sort index

# %%
df6.sort_values(by = ['id','Rating'], ascending = False, inplace = True)
df6

# %%
colmn = ['Brand', 'id', 'Rating']
df6.sort_values(by = colmn, ascending = [True, False, False], inplace = True)
df6.head(15)

# %%
df6.sort_index(ascending = False)
df6.nlargest(10, 'Price') # this function takes only int column and no string column

# %%
df6.nsmallest(10, ['Price', 'Rating'], keep = 'first') # this function takes only int column and no string column

# %%
df7 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv')
df7.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)
df7.set_index('id', inplace = True)

col_lst = df['Brand'] == 'APPLE'
df7.loc[col_lst].describe() # loc function dont take only column need to pass either filter or rows too

# %% [markdown]
# Always try to pass loc function using only 1 groupby column
# With 2 group by column it will throw error, so first do using 1 groupby column and then add another groupby column

# %%
brand_group = df7.groupby(['Model'])
brand_group['Rating'].value_counts(normalize = True).loc['Inspiron'] 
# only pass value in loc which contains in column model and brand

# %%
brand_group['Rating'].agg('mean')
brand_group['Rating'].agg(['mean', 'median', 'min', 'max']).loc['ASUS'] 
#loc is only taking Brand bcoz 
#brand remain same and model changes

# %%
filtar = df7['Brand'] == 'APPLE'
onl_filt = df.loc[filtar]
#brand remain same and model changes

# %%
brand_group = df7.groupby(by = ['Brand', 'Model']) 
# whichever column is 1st in groupby, the value of that column should be passed in loc function
brand_group['Rating'].value_counts(normalize = True).loc['ASUS', 'VivoBook']

# %%
group1 = df7.groupby(['Brand'])
group1.get_group('ASUS').head()
# in groupby frame instead of loc function we use get_group()

# %%
bandar = brand_group['Processor'].value_counts(normalize = True).head(10)

# %%
test_brand_group = df7.groupby(['Processor', 'Brand', 'Model']) #can use (by = xyz) but, not necessary 
test_brand_group['Rating'].value_counts().loc['i5'] #loc[1,2,3]
#test_brand_group as df

# %%
brand_group['Model'].apply(lambda x : x.str.contains('Vostro')).value_counts()

# %% [markdown]
# Same as above only changes is that value_counts is inside the paranthese

# %%
brand_vos =  brand_group['Model'].apply(lambda x : x.str.contains('Vostro').value_counts())

# %%
 pd.concat([onl_filt, bandar], axis = 0, sort = False) #  OR axis = 1

# %%
lst_na = ['NaN']
df8 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv', na_values = lst_na)
df8.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)
df8.set_index('id')

df8.dropna(axis = 'index', how = 'all')
df8.dropna(axis = 'columns', how = 'all')

# %%
df8.dropna(axis = 'columns', how = 'any')

# %% [markdown]
# 1. All - In all, All condition should satisfy in order to drop column or rows
# 2. any - if any one also satisfy remove the rows or column**

# %%
df8.dropna(axis = 'index', how = 'all', subset = ['Model', 'Series']) # by defult how is all

# %%
df8.head()

# %%
df8.agg(['sum', 'mean', 'median'])

# %%
df9 = pd.read_csv('../input/latest-laptop-price-list/Laptop.csv', index_col = 'Unnamed: 0')
df9.rename(columns = {'Unnamed: 0' : 'id'}, inplace = True)

# %%
df9.isna()

# %%
df.to_json('Users\ROSHAN D K\Desktop\json folder.json', orient = 'records', lines = True)

# %%
df8 = pd.read_json('Users\ROSHAN D K\Desktop\roshan_jsonfile.json', orient = 'records', lines = True)

# %%
df8.head()
